# %% [markdown]
# # PRIS data Analysis
# In this notebook I will analyze the content downloaded from the IAEA 2023 report on Nuclear Power Reactors in the world.
#
# ## Step 0: Combining data in one database
# The interesting data is from tables 9 to 14, they contain:
# - TABLE 9. CONSTRUCTION STARTS DURING 2023
# - TABLE 10. CONNECTIONS TO THE GRID DURING 2023
# - TABLE 11. SCHEDULED CONNECTIONS TO THE GRID DURING 2023
# - TABLE 12. REACTORS PLANNED FOR CONSTRUCTION AS KNOWN ON 31 DEC. 2023
# - TABLE 13. REACTORS UNDER CONSTRUCTION, 31 DEC. 2023
# - TABLE 14. OPERATIONAL REACTORS, 31 DEC. 2023
# So we are going to combine the lists and add a new label for their status

# %%
#%pip install pandas
import pandas as pd

# %%
pris_DB_columns = [
    "Country", "Code", "Reactor Name", "Type", "Model", "Thermal Capacity (MWth)", "Gross Capacity (MWe)", "Net Capacity (MWe)",
    "Operator", "nsss Supplier", "Construction Starts", "Grid Connection", "Availability", "Capacity Factor","Status"
]

# %% [markdown]
# Construction starts this Year 2023

# %%
# Read Excel file /data/IAEA - PRIS data/2023-Table9.xlsx
file_path = './IAEA - PRIS data/2023-Table9.xlsx'
# Ignore rows
skip_rows = [0, 1, 2, 11, 12]
df = pd.read_excel(file_path, skiprows=skip_rows, header=None)

# Ignore columns
skip_columns = [0,12,13]
df = df.drop(columns=skip_columns)

# Skip the rows used for the original column names and reset index
df = df.iloc[2:].reset_index(drop=True)

# Add new column
df["Grid Connection"] = "TBD"
df["Availability"] = "TBD"
df["Capacity Factor"] = "TBD"
df["Status"] = "Construction starts 2023"

# Rename Columns
df.columns = pris_DB_columns
# Populate empty columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Rename
df_StartsConstruction = df.copy()

# %% [markdown]
# Connected in 2023

# %%
# Read Excel file /data/IAEA - PRIS data/2023-Table9.xlsx
file_path = './IAEA - PRIS data/2023-Table10.xlsx'
# Ignore rows
skip_rows = [0, 1, 2, 3, 11, 12]
df = pd.read_excel(file_path, skiprows=skip_rows, header=None)

# Ignore columns
skip_columns = [0,12]
df = df.drop(columns=skip_columns)

# Skip the rows used for the original column names and reset index
df = df.iloc[2:].reset_index(drop=True)

# Add new column
df["Availability"] = "TBD"
df["Capacity Factor"] = "TBD"
df["Status"] = "Connected in 2023"
# Rename Columns
df.columns = pris_DB_columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Rename
df_JustConnected = df.copy()

# %% [markdown]
# Scheduled Connection in the next year (2024)

# %%
# Read Excel file
file_path = './IAEA - PRIS data/2023-Table11.xlsx'
# Ignore rows
skip_rows = [0, 1, 2, 3, 11, 12]
df = pd.read_excel(file_path, skiprows=skip_rows, header=None)

# Ignore columns
skip_columns = [0,12]
df = df.drop(columns=skip_columns)

# Skip the rows used for the original column names and reset index
df = df.iloc[2:].reset_index(drop=True)

# Add new column
df["Availability"] = "TBD"
df["Capacity Factor"] = "TBD"
df["Status"] = "Connection Scheduled Soon"
# Rename Columns
df.columns = pris_DB_columns


# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Rename
df_ScheduledConnection = df.copy()

# %% [markdown]
# Planned Construction

# %%
# Read Excel file
file_path = './IAEA - PRIS data/2023-Table12.xlsx'
# Ignore rows
skip_rows = [0, 1, 2, 3, 11, 53, 54]
df = pd.read_excel(file_path, skiprows=skip_rows, header=None)

# Ignore columns
skip_columns = [0]
df = df.drop(columns=skip_columns)

# Skip the rows used for the original column names and reset index
df = df.iloc[2:].reset_index(drop=True)

# Add new column
df["Grid Connection"] = "TBD"
df["Availability"] = "TBD"
df["Capacity Factor"] = "TBD"
df["Status"] = "Construction Planned"
# Rename Columns
df.columns = pris_DB_columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Where Construction Starts is empty put TBD
df["Construction Starts"] = df["Construction Starts"].replace(["", None, pd.NA], "TBD")

# Rename
df_PlannedConstruction = df.copy()

# %%
# Read Excel file
file_path = './IAEA - PRIS data/2023-Table13.xlsx'
# Ignore rows
skip_rows = [0, 1, 2, 3, 65, 66]
df = pd.read_excel(file_path, skiprows=skip_rows, header=None)

# Ignore columns
skip_columns = [0,2,13,15]
df = df.drop(columns=skip_columns)

# Skip the rows used for the original column names and reset index
df = df.iloc[2:].reset_index(drop=True)

# Add new column
df["Grid Connection"] = "TBD"
df["Availability"] = "TBD"
df["Status"] = "Under Construction"

# Rename Columns
df.columns = pris_DB_columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Replace empty values with TBD
df["Grid Connection"] = df["Grid Connection"].replace(["", None, pd.NA], "TBD")

# Rename Columns
df.columns = pris_DB_columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Rename
df_UnderConstruction = df.copy()

# %% [markdown]
# Operational Reactors as of 2023

# %%
# Read Excel file
file_path = './IAEA - PRIS data/2023-Table14.xlsx'
# Ignore rows
skip_rows = [417, 418, 419, 420, 421, 422, 423]
df = pd.read_excel(file_path, skiprows=skip_rows, header=None)
# Ignore columns
skip_columns = [0,13,16,17,18]
df = df.drop(columns=skip_columns)

# Skip the rows used for the original column names and reset index
df = df.iloc[6:].reset_index(drop=True)

# Add new column
df["Status"] = "Under Construction"

# Rename Columns
df.columns = pris_DB_columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()


# Rename Columns
df.columns = pris_DB_columns

# Forward fill only on the first column since they used merged cells
df["Country"] = df["Country"].ffill()

# Rename
df_Operational = df.copy()

# %% [markdown]
# The interesting data is from tables 9 to 14, they contain:
# - TABLE 9. CONSTRUCTION STARTS DURING 2023
# - TABLE 10. CONNECTIONS TO THE GRID DURING 2023
# - TABLE 11. SCHEDULED CONNECTIONS TO THE GRID DURING 2024
# - TABLE 12. REACTORS PLANNED FOR CONSTRUCTION AS KNOWN ON 31 DEC. 2023
# - TABLE 13. REACTORS UNDER CONSTRUCTION, 31 DEC. 2023
# - TABLE 14. OPERATIONAL REACTORS, 31 DEC. 2023
#
# We can group some of this:
# Connection during 2023 and scheduled connections during 2024 can all be grouped in "ScheduledConnection" status
# Construction starts 2023 and under construction all "UnderConstrcion"
# Then we have operationl and planned

# %%
df_StartsConstruction["Status"] = "Under Construction"
df_UnderConstruction["Status"] = "Under Construction"

df_PlannedConstruction["Status"] = "Planned Construction"

df_JustConnected["Status"] = "Scheduled Connected"
df_ScheduledConnection["Status"] = "Scheduled Connection"

df_Operational["Status"] = "Operational"

# Unite all DataFrames
df_Complete = pd.concat([df_StartsConstruction, df_UnderConstruction, df_PlannedConstruction, df_JustConnected, df_ScheduledConnection, df_Operational], ignore_index=True)

# Display the final DataFrame
pd.options.display.max_columns = None  # Show all columns
display(df_Complete)
# Out:
#     Country      Code   Reactor Name   Type           Model  \
# 0     CHINA  CN -75        HAIYANG-4  PWR           CAP1000
# 1     CHINA  CN -79      LIANJIANG-1  PWR           CAP1000
# 2     CHINA  CN -77         LUFENG-6  PWR           HPR1000
# 3     CHINA  CN -73         SANMEN-4  PWR           CAP1000
# 4     CHINA  CN -81         XUDABU-1  PWR           CAP1000
# ..      ...       ...            ...    ...             ...
# 527     USA  US -499   SOUTH TEXAS-2  PWR    WH 4LP (DRYAMB
# 528     USA  US -5025       VOGTLE-3  PWR           AP-1000
# 529     USA  US -528    PALO VERDE-1  PWR    CE80 2LP (DRYA
# 530     USA  US -529    PALO VERDE-2  PWR    CE80 2LP (DRYA
# 531     USA  US -530    PALO VERDE-3  PWR    CE80 2LP (DRYA
#
#     Thermal Capacity (MWth) Gross Capacity (MWe) Net Capacity (MWe)  Operator  \
# 0                      3400                 1253               1161     SDNPC
# 1                      3400                 1224               1224     ZJNPC
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def extract_year(val):
    if pd.isna(val):
        return np.nan
    s = str(val).strip()
    if s.upper() == "TBD" or s == "":
        return np.nan
    try:
        return int(s.split('-')[0])
    except Exception:
        return np.nan

# parse grid years
grid_years = df_Complete['Grid Connection'].apply(extract_year)

# remove anything with 'TBD' in Grid Connection or Construction Starts
starts_str = df_Complete['Construction Starts'].astype(str).str.strip().str.upper()
mask_no_tbd = (~grid_years.isna()) & (~starts_str.eq('TBD'))

# remove construction/planned statuses
mask_no_construction = ~df_Complete['Status'].astype(str).str.contains(r'Construction|Planned', case=False, na=False)

# final mask
mask = mask_no_tbd & mask_no_construction
df_plot = df_Complete[mask].copy()

if df_plot.empty:
    print("No data to plot after removing 'TBD' and construction/planned entries.")
else:
    years = df_plot['Grid Connection'].apply(extract_year).astype(int)
    counts = years.value_counts().sort_index()
    full_idx = np.arange(counts.index.min(), counts.index.max() + 1)
    counts_full = counts.reindex(full_idx, fill_value=0)
    cumulative = counts_full.cumsum()
    plt.rcParams.update({'font.size': 16})
    plt.figure(figsize=(10, 6))
    plt.plot(full_idx, cumulative, linestyle='-', color='tab:blue')
    plt.fill_between(full_idx, cumulative, color='tab:blue', alpha=0.22, step='pre')

    # Remove scatter points
    # plt.scatter(full_idx, cumulative, color='tab:blue', s=12)  # Commented out

    # Add vertical lines for Chernobyl (1986) and Fukushima (2011)
    plt.axvline(x=1986, color='red', linestyle='--', alpha=0.7, label='Chernobyl (1986)')
    plt.axvline(x=2011, color='orange', linestyle='--', alpha=0.7, label='Fukushima (2011)')

    plt.xlabel('Year of Connection to the Grid')
    plt.ylabel('Number of reactors')
    plt.grid(alpha=0.3)
    plt.ylim(bottom=0)
    plt.xlim(1965, 2024)

    # Set xticks every decade
    decade_ticks = np.arange((full_idx.min() // 10) * 10, full_idx.max() + 1, 10)
    plt.xticks(decade_ticks, rotation=45)

    # Add legend for the vertical lines
    plt.legend()

    plt.tight_layout()
    plt.savefig('reactors_grid_connection_cumulative.png', dpi=300)

    plt.show()

    removed = len(df_Complete) - len(df_plot)
    print(f"Plotted {len(df_plot)} reactors. Removed {removed} rows (TBD or construction/planned).")
# Out:
# Plotted 421 reactors. Removed 111 rows (TBD or construction/planned).

# %%
# List all Countries
countries = df_Complete["Country"].unique()
display(countries)
# Out:
# array(['CHINA', 'EGYPT', 'ARGENTINA', 'BANGLADESH', 'BRAZIL', 'FRANCE',
#        'INDIA', 'IRAN,ISL.REP', 'JAPAN', 'KOREA,REP.OF', 'RUSSIA',
#        'SLOVAKIA', 'TÜRKIYE', 'UAE', 'UK', 'UKRAINE', 'USA', 'FINLAND',
#        'HUNGARY', 'BELARUS', 'ARMENIA', 'BELGIUM', 'BULGARIA', 'CANADA',
#        'CZECH REP.', 'MEXICO', 'NETHERLANDS', 'PAKISTAN', 'ROMANIA',
#        'SLOVENIA', 'SOUTH AFRICA', 'SPAIN', 'SWEDEN', 'SWITZERLAND'],
#       dtype=object)

# %%
# Exclude countries known to only work within its orders
To_exclude = ['CHINA', 'RUSSIA', 'IRAN', 'INDIA', 'BELARUS', 'PAKISTAN']
# Exclude this from the df
df_Countries_Filtered = df_Complete[~df_Complete["Country"].isin(To_exclude)]

# %%
# List all nsss Suppliers
nsss_suppliers = df_Countries_Filtered["nsss Supplier"].unique()
display(nsss_suppliers)
# Out:
# array(['JSC ASE', 'CNEA', 'AEM', 'KWU', 'FRAM', 'H/G', 'HITACHI',
#        'DHICKOPC', 'ŠKODA ', 'KEPCO', 'ORANO', 'WH', nan, 'MHI',
#        'SIEMENS', 'AECL', 'FAEA', 'ACECOWEN', 'ACLF', 'AEE', 'OH/AECL',
#        'ASEASTAL', 'WH/MHI', 'DHICKAEC', 'AECL/DHI', 'GE', 'S/KWU',
#        'ABB ATOM', 'GETSCO', 'NPC', 'NNC', 'PPC', 'PAIP', 'PAA', 'B&W',
#        'CE'], dtype=object)

# %%
operator_country_array = [
    ["JSC ASE", "Russia"],
    ["CNEA", "Argentina"],
    ["AEM", "Russia"],
    ["KWU", "Germany"],
    ["FRAM", "France"],
    ["H/G", "Japan"],
    ["HITACHI", "Japan"],
    ["DHICKOPC", "Korea"],
    ["ŠKODA", "Czech"],
    ["KEPCO", "Korea"],
    ["ORANO", "France"],
    ["WH", "US"],
    ["nan", "Japan (GE Hitachi Nuclear Energy or Toshiba)"],
    ["MHI", "US/Japan"],
    ["SIEMENS", "Germany"],
    ["AECL", "Canada"],
    ["FAEA", "US"],
    ["ACECOWEN", "US/Belgium"],
    ["ACLF", "France/Belgium"],
    ["AEE", "Russia"],
    ["OH/AECL", "Canada"],
    ["ASEASTAL", "Finland"],
    ["WH/MHI", "Japan/US"],
    ["DHICKAEC", "Korea"],
    ["AECL/DHI", "Canada"],
    ["GE", "US"],
    ["S/KWU", "Germany"],
    ["ABB ATOM", "Sweden"],
    ["GETSCO", "US"],
    ["NPC", "UK"],
    ["NNC", "UK"],
    ["PPC", "UK"],
    ["PAIP", "Russia"],
    ["PAA", "Russia"],
    ["B&W", "US"],
    ["CE", "US"]
]
# get those that contain in the second element one of the countries from To_Exclude
filtered_operators = [op for op in operator_country_array if op[1].upper() not in To_exclude]
# filtered_operators = [[op[0].upper(), op[1].upper()] for op in filtered_operators]
print("Operators that are not in the excluded countries:")
for op in filtered_operators:
    print(f" - {op[0]} ({op[1]})")
# Out:
# Operators that are not in the excluded countries:
#  - CNEA (Argentina)
#  - KWU (Germany)
#  - FRAM (France)
#  - H/G (Japan)
#  - HITACHI (Japan)
#  - DHICKOPC (Korea)
#  - ŠKODA (Czech)
#  - KEPCO (Korea)
#  - ORANO (France)
#  - WH (US)
#  - nan (Japan (GE Hitachi Nuclear Energy or Toshiba))
#  - MHI (US/Japan)
#  - SIEMENS (Germany)
#  - AECL (Canada)
#  - FAEA (US)
#  - ACECOWEN (US/Belgium)
#  - ACLF (France/Belgium)
#  - OH/AECL (Canada)
#  - ASEASTAL (Finland)
#  - WH/MHI (Japan/US)
#  - DHICKAEC (Korea)
#  - AECL/DHI (Canada)
#  - GE (US)
#  - S/KWU (Germany)
#  - ABB ATOM (Sweden)
#  - GETSCO (US)
#  - NPC (UK)
#  - NNC (UK)
#  - PPC (UK)
#  - B&W (US)
#  - CE (US)

# %%
# Filter out operators from excluded countries from the df
df_Countries_Filtered_2 = df_Countries_Filtered[df_Countries_Filtered["nsss Supplier"].isin([op[0] for op in filtered_operators])]
display(df_Countries_Filtered_2)
# Out:
#        Country      Code   Reactor Name   Type           Model  \
# 6    ARGENTINA  AR -4           CAREM25  PWR    CAREM Prototyp
# 9       BRAZIL  BR -3           ANGRA-3  PWR        PRE KONVOI
# 37      FRANCE  FR -74    FLAMANVILLE-3  PWR               EPR
# 47       JAPAN  JP -66             OHMA  BWR              ABWR
# 48       JAPAN  JP -65        SHIMANE-3  BWR              ABWR
# ..         ...       ...            ...    ...             ...
# 527        USA  US -499   SOUTH TEXAS-2  PWR    WH 4LP (DRYAMB
# 528        USA  US -5025       VOGTLE-3  PWR           AP-1000
# 529        USA  US -528    PALO VERDE-1  PWR    CE80 2LP (DRYA
# 530        USA  US -529    PALO VERDE-2  PWR    CE80 2LP (DRYA
# 531        USA  US -530    PALO VERDE-3  PWR    CE80 2LP (DRYA
#
#     Thermal Capacity (MWth) Gross Capacity (MWe) Net Capacity (MWe)  Operator  \
# 6                       100                   29                 25      CNEA
# ...

# %%
# Only consider those with a grid connection that is either TBD or after 1986 (yyyy-mm format)
def age_limit(val):
    if val == "TBD":
        return True
    try:
        year = int(str(val).split('-')[0])
        return year > 2000
    except Exception:
        return False
# Either apply it to the grid connection or the construction starting date, the result is basically the same
df_Age_Filtered = df_Countries_Filtered_2[df_Countries_Filtered_2["Construction Starts"].apply(age_limit)]
display(df_Age_Filtered)
# Out:
#           Country      Code            Reactor Name   Type           Model  \
# 6       ARGENTINA  AR -4                    CAREM25  PWR    CAREM Prototyp
# 9          BRAZIL  BR -3                    ANGRA-3  PWR        PRE KONVOI
# 37         FRANCE  FR -74             FLAMANVILLE-3  PWR               EPR
# 47          JAPAN  JP -66                      OHMA  BWR              ABWR
# 48          JAPAN  JP -65                 SHIMANE-3  BWR              ABWR
# 49   KOREA,REP.OF  KR -29                   SAEUL-3  PWR          APR-1400
# 50   KOREA,REP.OF  KR -30                   SAEUL-4  PWR          APR-1400
# 59            UAE  AE -04                 BARAKAH-4  PWR          APR-1400
# 60             UK  GB -25A        HINKLEY POINT C-1  PWR          EPR-1750
# 61             UK  GB -25B        HINKLEY POINT C-2  PWR          EPR-1750
# 64            USA  US -5026                VOGTLE-4  PWR           AP-1000
# ...

# %%
models = df_Age_Filtered["Model"].unique()
print(len(models), "unique models found:")
for m in models:
    print(f"- {m}")
# Out:
# 9 unique models found:
# - CAREM Prototyp
# - PRE KONVOI
# - EPR
# - ABWR
# - APR-1400
# - EPR-1750
# - AP-1000
# - APWR
# - OPR-1000

# %%
models_to_study = ["EPR", "APR-1400", "EPR-1750", "AP-1000", "APWR"]
df_filtered_models = df_Countries_Filtered[df_Countries_Filtered["Model"].isin(models_to_study)]

# %%
# Let's see each model in more detail
for m in models_to_study:
    display(m)
    display(df_filtered_models[df_filtered_models["Model"] == m])
# Out:
# 'EPR'
#      Country      Code   Reactor Name   Type Model Thermal Capacity (MWth)  \
# 37    FRANCE  FR -74    FLAMANVILLE-3  PWR     EPR                    4300
# 220  FINLAND  FI -5       OLKILUOTO-3  PWR     EPR                    4300
#
#     Gross Capacity (MWe) Net Capacity (MWe) Operator nsss Supplier  \
# 37                  1650               1630      EDF          FRAM
# 220                 1660               1600      TVO          FRAM
#
#     Construction Starts Grid Connection Availability Capacity Factor  \
# 37              2007-12             TBD          TBD             TBD
# 220             2005-8          2022-3          96.3            96.9
#
#                  Status
# 37   Under Construction
# 220         Operational
# 'APR-1400'
#           Country      Code  Reactor Name   Type     Model  \
# 49   KOREA,REP.OF  KR -29         SAEUL-3  PWR    APR-1400
# 50   KOREA,REP.OF  KR -30         SAEUL-4  PWR    APR-1400
# ...

# %% [markdown]
# ### Model review
# I will now look at each model to understand if:
# - They are still available to be constructed as new
# - The country that builds it does export it or if its only for internal use

# %%
df_Complete[df_Complete['Country'] == 'CHINA']
# Out:
#     Country      Code     Reactor Name   Type    Model  \
# 0     CHINA  CN -75          HAIYANG-4  PWR    CAP1000
# 1     CHINA  CN -79        LIANJIANG-1  PWR    CAP1000
# 2     CHINA  CN -77           LUFENG-6  PWR    HPR1000
# 3     CHINA  CN -73           SANMEN-4  PWR    CAP1000
# 4     CHINA  CN -81           XUDABU-1  PWR    CAP1000
# ..      ...       ...              ...    ...      ...
# 205   CHINA  CN -55    FANGCHENGGANG-3  PWR    HPR1000
# 206   CHINA  CN -6           LING AO-1  PWR       M310
# 207   CHINA  CN -7           LING AO-2  PWR       M310
# 208   CHINA  CN -8         QINSHAN 3-1  PHWR   CANDU 6
# 209   CHINA  CN -9         QINSHAN 3-2  PHWR   CANDU 6
#
#     Thermal Capacity (MWth) Gross Capacity (MWe) Net Capacity (MWe) Operator  \
# 0                      3400                 1253               1161    SDNPC
# 1                      3400                 1224               1224    ZJNPC
# ...

# %%
# Reconstruct df to have number of reactors by country
df_reactors_by_country = df_Complete.groupby(['Country', 'Status']).size().unstack(fill_value=0).reset_index()
df_reactors_by_country['Operational'] = df_reactors_by_country.get('Operational', 0) + df_reactors_by_country.get('Scheduled Connected', 0)
df_reactors_by_country = df_reactors_by_country.drop(columns=['Scheduled Connected'])
# Combine "scheduled connected" and "scheduled connection" and "under construction" into "under construction"
df_reactors_by_country['Under Construction'] = df_reactors_by_country.get('Under Construction', 0) + df_reactors_by_country.get('Scheduled Connection', 0)
# Drop the now redundant columns
df_reactors_by_country = df_reactors_by_country.drop(columns='Scheduled Connection')
# Add a new column with total reactors per country
df_reactors_by_country['Total Reactors'] = df_reactors_by_country.sum(axis=1, numeric_only=True)
# Display
display(df_reactors_by_country)
# Out:
# Status       Country  Operational  Planned Construction  Under Construction  \
# 0          ARGENTINA            3                     0                   1
# 1            ARMENIA            1                     0                   0
# 2         BANGLADESH            0                     0                   2
# 3            BELARUS            3                     0                   0
# 4            BELGIUM            5                     0                   0
# 5             BRAZIL            2                     0                   1
# 6           BULGARIA            2                     0                   0
# 7             CANADA           19                     0                   0
# 8              CHINA           56                     9                  30
# 9         CZECH REP.            6                     0                   0
# 10             EGYPT            0                     1                   4
# ...

# %%
# Sort the DataFrame by 'Total Reactors' descending
df_sorted = df_reactors_by_country.sort_values('Total Reactors', ascending=False)

# Extract data for plotting
countries_plot = df_sorted['Country'].tolist()
operable = df_sorted['Operational'].values
under_construction = df_sorted['Under Construction'].values
planned = df_sorted['Planned Construction'].values

# Create the plot
fig, ax = plt.subplots(figsize=(12, 10))

# Stacked bars with blue tones
ax.barh(countries_plot, operable, label='Operable', color='#1f77b4')
ax.barh(countries_plot, under_construction, left=operable, label='Under Construction', color='#6baed6')
ax.barh(countries_plot, planned, left=np.add(operable, under_construction), label='Planned', color='#9ecae1')

# Labels and title with font size 16
ax.set_xlabel('Number of Reactors', fontsize=16)
ax.set_title('Number of Reactors by Country (Operable, Under Construction, Planned)', fontsize=16)

# Legend and tick parameters
ax.legend(loc='lower right', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=14)

# Invert y-axis to have the largest on top
ax.invert_yaxis()

# Save and show
plt.tight_layout()
plt.savefig('reactors_by_country.png', format='PNG', dpi=200, bbox_inches='tight')
plt.show()
