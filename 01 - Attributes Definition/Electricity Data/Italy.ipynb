# %%
#import Popolazione residente.csv
import pandas as pd
df = pd.read_csv('Popolazione residente.csv', sep=',')
df.head()
# Out:
#    Codice regione                       Regione   Celibi  Coniugati  \
# 0               1                      Piemonte   989655     932829
# 1               2  Valle d'Aosta/Vallée d'Aoste    30492      25112
# 2               3                     Lombardia  2438816    2181183
# 3               4  Trentino-Alto Adige/Südtirol   281302     223992
# 4               5                        Veneto  1156616    1084966
#
#    Divorziati  Vedovi  Uniti civilmente  \
# 0       89408   63113              2174
# 1        2996    1673                41
# 2      173482  126937              6244
# 3       18754   11414               421
# 4       84137   60475              1972
#
#    Maschi già in unione civile (per scioglimento unione)  \
# 0                                                 78
# 1                                                  1
# 2                                                195
# 3                                                 13
# 4                                                 64
#
#    Maschi già in unione civile (per decesso del partner)  Totale maschi  \
# 0                                                 45            2077302
# 1                                                  2              60317
# 2                                                146            4927003
# 3                                                  7             535903
# 4                                                 32            2388262
#
#     Nubili  Coniugate  Divorziate  Vedove  Unite civilmente  \
# 0   822799     943085      124251  282733              1361
# 1    25414      25281        4040    7786                37
# 2  2059292    2199459      240894  581983              3207
# 3   240054     225746       25270   55434               274
# 4   970647    1093427      112188  286530              1091
#
#    Femmine già in unione civile (per scioglimento unione)  \
# 0                                                 81
# 1                                                  2
# 2                                                178
# 3                                                 20
# 4                                                 62
#
#    Femmine già in unione civile (per decesso del partner)  Totale femmine  \
# 0                                                 11              2174321
# 1                                                  0                62560
# 2                                                 38              5085051
# 3                                                  1               546799
# 4                                                  9              2463954
#
#      Totale
# 0   4251623
# 1    122877
# 2  10012054
# 3   1082702
# 4   4852216

# %%
nort_bidding_zone =["Piemonte", "Lombardia", "Veneto", "Friuli Venezia Giulia", "Trentino Alto Adige", "Emilia Romagna", "Valle d'Aosta", "Liguria"]
print(len(nort_bidding_zone))
total_population = df["Totale"].sum()
north_population = df[df["Regione"].isin(nort_bidding_zone)]["Totale"].sum()
north_population_percentage = (north_population / total_population) * 100
print(f"Total Population: {total_population}")  
print(f"North Population: {north_population}")
print(f"North Population Percentage: {north_population_percentage:.2f}%")
# Out:
# 8
# Total Population: 58971230
# North Population: 20625033
# North Population Percentage: 34.97%
